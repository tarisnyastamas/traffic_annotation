# %%
import pandas as pd
import json
import textdistance

# %%
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      |████████████████████████████████| 9.7 MB 5.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 510 kB 4.2 MB/s eta 0:00:01
# ...

# %%
pip install textdistance
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pwd
# Out:
# /home/bence/skool/2nd_semester/nlp/traffic_annotation

# %%
# !ls
# Out:
#  cities_coords.json  'NLP projekt.xlsx'   README.md   traffic_annotation.ipynb

# %%
data_path = '/home/bence/skool/2nd_semester/nlp/traffic_annotation/'
df = pd.read_excel(data_path + 'NLP projekt.xlsx')
# df = df['Corpus']
df = df.dropna()
df
# Out:
#                                                Corpus
# 0   Csík fele a Hargita és az Anna fogadó között e...
# 1                         Farkaslakán mérnek óvatosan
# 2                       Liban végében  sétál az úton!
# 3                 Nagygalambfalva központ állítgatnak
# 4        Szejkén 17:30 kor, maci.. az úton szaladt át
# ..                                                ...
# 94  Tordán egy tehén csorda elfoglalta az utat. Ne...
# 95      Vagyason radaroznak a régi cérnagyár mellett.
# 96  Sajnos sokat ittam és Uzonon lerobbant autóm a...
# 97  Egy szemét szállító felborult az E36-oson, tor...
# 98  Kérdezem én, hogy miért nem tudják már megcsin...
#
# [99 rows x 1 columns]

# %% [markdown]
# ## Removing accents

# %%
replacements = {
    "Á": "A",
    "É": "E",
    "á": "a",
    "é": "e",
    "í": "i",
    "Ó": "O",
    "ó": "o",
    "Ö": "O",
    "ö": "o",
    "Ő": "O",
    "ő": "o",
    "Ú": "U",
    "ú": "u",
    "Ű": "U",
    "ű": "u",
    "ü": "u",
    "Í": "I"
}

def clean_text_accents(text, replacements=replacements):
    text = "".join([replacements.get(c, c) for c in text])
    return text

# %%
df['Corpus'] = [clean_text_accents(i) for i in df['Corpus']]
df
# Out:
#                                                Corpus
# 0   Csik fele a Hargita es az Anna fogado kozott e...
# 1                         Farkaslakan mernek ovatosan
# 2                       Liban vegeben  setal az uton!
# 3                 Nagygalambfalva kozpont allitgatnak
# 4        Szejken 17:30 kor, maci.. az uton szaladt at
# ..                                                ...
# 94  Tordan egy tehen csorda elfoglalta az utat. Ne...
# 95      Vagyason radaroznak a regi cernagyar mellett.
# 96  Sajnos sokat ittam es Uzonon lerobbant autom a...
# 97  Egy szemet szallito felborult az E36-oson, tor...
# 98  Kerdezem en, hogy miert nem tudjak mar megcsin...
#
# [99 rows x 1 columns]

# %%
data_path
# Out:
# '/home/bence/skool/2nd_semester/nlp/traffic_annotation/'

# %%
data_path
json_data = pd.read_json(data_path + 'coords2.json')

# %%
with open('/home/gabor/Traffic annotation/coords2.json') as json_file:
    data_ro = json.load(json_file)

# %%
with open('/home/gabor/Traffic annotation/hun2.json') as json_file:
    data_hu = json.load(json_file)
len(data_hu)
# Out:
# 20

# %%
cities_hu = {}
i = 0
for key, value in data_hu.items():
    print("---" + key + "---")
    
    for key2, value2 in value.items():
#         print("\t", key2, "->", value2)
        cities_hu[key2] = value2
        i += 1
print("processed %d items" % i)
# Out:
# ---CLUJ---
# ---COVASNA---
# ---MARAMURES---
# ---TIMIS---
# ---HARGHITA---
# ---ALBA---
# ---SUCEAVA---
# ---NEAMT---
# ---BISTRITA-NASAUD---
# ---SIBIU---
# ---MURES---
# ---HUNEDOARA---
# ---SALAJ---
# ---CARAS-SEVERIN---
# ---SATU MARE---
# ---MEHEDINTI---
# ---ARAD---
# ---BIHOR---
# ---BACAU---
# ---BRASOV---
# processed 1086 items

# %%
len(cities_hu)
# Out:
# 1057

# %%
len(data_hu)
# Out:
# 77

# %%
len(data_ro['DOLJ'])
# Out:
# 392

# %%
# create flat dict
coords_all = {}
i = 0
for key, value in data_ro.items():
    print("----" + key + "----")
    
    for key2, value2 in value.items():
#         print("\t", key2, value2)
        coords_all[key2] = value2
        i += 1
print("processed %d items" % i)
# Out:
# ----DOLJ----
# ----ARAD----
# ----SALAJ----
# ----CALARASI----
# ----VRANCEA----
# ----HARGHITA----
# ----SATU MARE----
# ----MEHEDINTI----
# ----IALOMITA----
# ----BACAU----
# ----IASI----
# ----MARAMURES----
# ----TELEORMAN----
# ----NEAMT----
# ----GIURGIU----
# ----BISTRITA-NASAUD----
# ----BUCURESTI----
# ----OLT----
# ----VASLUI----
# ----BRASOV----
# ----GALATI----
# ----CLUJ----
# ----ILFOV----
# ----ALBA----
# ----SUCEAVA----
# ----MURES----
# ----MUNICIPIUL BUCURESTI----
# ----GORJ----
# ----ARGES----
# ----HUNEDOARA----
# ----TULCEA----
# ----VALCEA----
# ----BRAILA----
# ----BUZAU----
# ----TIMIS----
# ----CONSTANTA----
# ----SIBIU----
# ----COVASNA----
# ----DAMBOVITA----
# ----CARAS-SEVERIN----
# ----BIHOR----
# ----PRAHOVA----
# ----BOTOSANI----
# processed 13649 items

# %%
len(coords_all)
# Out:
# 10529

# %%
cities_hu
# Out:
# {'POIENI': 'Kissebes',
#  'FRATA': 'Magyarfráta',
#  'PLOSCOS': 'Palackos',
#  'VALEA IERII': 'Járavize',
#  'ICLOD': 'Nagyiklód',
#  'FIZESU GHERLII': 'Ördöngösfüzes',
#  'CALARASI': 'Harasztos',
#  'MAGURI-RACATAU': 'Reketó',
#  'SANDULESTI': 'Szind',
#  'PALATCA': 'Magyarpalatka',
#  'SIC': 'Szék',
#  'SACUIEU': 'Székelyjó',
#  'MOLDOVENESTI': 'Várfalva',
#  'CALATELE': 'Kiskalota',
#  'CEANU MARE': 'Mezőcsán',
#  'DABACA': 'Doboka',
#  'CHINTENI': 'Kajántó',
#  'VIISOARA': 'Érszőllős',
#  'ALUNIS': 'Magyaró',
#  'MINTIU GHERLII': 'Szamosújvárnémeti',
#  'PETRESTII DE JOS': 'Magyarpeterd',
#  'CAPUSU MARE': 'Magyarkapus',
#  'MUNICIPIUL CAMPIA TURZII': 'Aranyosgyéres',
#  'IZVORU CRISULUI': 'Körösfő',
#  'ORAS HUEDIN': 'Bánffyhunyad',
#  'BOBALNA': 'Alparét',
#  'BORSA': 'Kolozsborsa',
#  'BACIU': 'Kisbács',
#  'AGHIRESU': 'Egeres',
#  'BAISOARA': 'Járabánya',
#  'CAMARASU': 'Pusztakamarás',
#  'MUNICIPIUL TURDA': 'Torda',
#  'MUNICIPIUL CLUJ-NAPOCA': 'Kolozsvár',
# ...

# %%
coords_all
# Out:
# {'TEASC': [23.864607449661804, 44.164544523206956],
#  'SALCUTA': [25.581031739620805, 44.64373857391277],
#  'POPEASA': [23.735648601467, 44.49479526188053],
#  'CIOROIASI': [23.451646351952395, 44.08543346022407],
#  'GAIA': [23.84619495668449, 44.5159075507591],
#  'TAMBURESTI': [23.93602000670995, 44.02778991920048],
#  'SEGARCEA': [23.741970086538874, 44.094343937893846],
#  'MOTATEI': [23.20289656964323, 44.09612882114163],
#  'MOFLESTI': [23.751816205779015, 44.659428144039715],
#  'POIANA FANTANII': [23.366673012799676, 44.514290171126305],
#  'BOBEANU': [24.07688412916652, 44.27296509886632],
#  'GOGOSITA': [23.359144266638523, 44.39900018847287],
#  'BRADESTI': [23.469971306110534, 46.332834319668635],
#  'BECHET': [24.179591470339037, 44.39471853882703],
#  'FILARET': [23.62342239384943, 44.00114474917575],
#  'MOTATEI GARA': [23.1930936662324, 44.03883656348569],
#  'PERISOR': [24.22718887200765, 47.314174221720435],
# ...

# %%
final_dict = {}
i = 0
for key, value in cities_hu.items():
    if key in coords_all:
        print(key, "->", value)
        
        final_dict[key] = {
            'name_hun': value,
            'coords_x': coords_all[key][0],
            'coords_y': coords_all[key][1]
        }
        
        i += 1

print("Found %d matches" % i)
# Out:
# POIENI -> Kissebes
# FRATA -> Magyarfráta
# PLOSCOS -> Palackos
# VALEA IERII -> Járavize
# ICLOD -> Nagyiklód
# FIZESU GHERLII -> Ördöngösfüzes
# CALARASI -> Harasztos
# MAGURI-RACATAU -> Reketó
# SANDULESTI -> Szind
# PALATCA -> Magyarpalatka
# SIC -> Szék
# SACUIEU -> Székelyjó
# MOLDOVENESTI -> Várfalva
# CALATELE -> Kiskalota
# CEANU MARE -> Mezőcsán
# DABACA -> Doboka
# CHINTENI -> Kajántó
# VIISOARA -> Érszőllős
# ALUNIS -> Magyaró
# MINTIU GHERLII -> Szamosújvárnémeti
# PETRESTII DE JOS -> Magyarpeterd
# CAPUSU MARE -> Magyarkapus
# MUNICIPIUL CAMPIA TURZII -> Aranyosgyéres
# IZVORU CRISULUI -> Körösfő
# ORAS HUEDIN -> Bánffyhunyad
# BOBALNA -> Alparét
# BORSA -> Kolozsborsa
# BACIU -> Kisbács
# AGHIRESU -> Egeres
# BAISOARA -> Járabánya
# CAMARASU -> Pusztakamarás
# MUNICIPIUL TURDA -> Torda
# MUNICIPIUL CLUJ-NAPOCA -> Kolozsvár
# MUNICIPIUL DEJ -> Dés
# MARISEL -> Havasnagyfalu
# VULTURENI -> Borsaújfalu
# RECEA-CRISTUR -> Récekeresztúr
# FLORESTI -> Szászfenes
# ...

# %%
len(final_dict)
# Out:
# 1047

# %%
with open('cities_coords.json', 'w') as outfile:
    json.dump(final_dict, outfile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-fc0d37d4eac4> in <module>
#       1 with open('cities_coords.json', 'w') as outfile:
# ----> 2     json.dump(final_dict, outfile)
#
# NameError: name 'final_dict' is not defined

# %%
# get cities from text
from nltk.tokenize import word_tokenize

cities_list = []
for i in df['Corpus']:
    for j in word_tokenize(i):
        if j[0].isupper() == True and j not in cities_list:
            cities_list.append(j)

# %%
# !ls
# Out:
#  cities_coords.json  'NLP projekt.xlsx'   README.md   traffic_annotation.ipynb

# %%
# !head -10 cities_coords.json
# Out:
# {"POIENI": {"name_hun": "Kissebes", "coords_x": 22.45403843259616, "coords_y": 45.801577439409826}, "FRATA": {"name_hun": "Magyarfr\u00e1ta", "coords_x": 24.05952346445536, "coords_y": 46.70548297873597}, "PLOSCOS": {"name_hun": "Palackos", "coords_x": 23.848019562312807, "coords_y": 46.64324682863738}, "VALEA IERII": {"name_hun": "J\u00e1ravize", "coords_x": 23.32876543645681, "coords_y": 46.644099374632816}, "ICLOD": {"name_hun": "Nagyikl\u00f3d", "coords_x": 23.93892860810773, "coords_y": 46.210305531372654}, "FIZESU GHERLII": {"name_hun": "\u00d6rd\u00f6ng\u00f6sf\u00fczes", "coords_x": 23.988215931383923, "coords_y": 47.025265123800885}, "CALARASI": {"name_hun": "Harasztos", "coords_x": 27.258112662952215, "coords_y": 47.60540890017327}, "MAGURI-RACATAU": {"name_hun": "Reket\u00f3", "coords_x": 23.197003629393212, "coords_y": 46.64499774692438}, "SANDULESTI": {"name_hun": "Szind", "coords_x": 24.648489903215005, "coords_y": 45.026835995573734}, "PALATCA": {"name_hun": "Magyarpal
# ...

# %% [markdown]
# ---

# %%
import json

with open('cities_coords1.json', encoding='UTF-8') as f:
    cities_dict = json.load(f)
    
print(cities_dict)
# Out:
# {'POIENI': {'name_hun': 'Kissebes', 'coords_x': 22.45403843259616, 'coords_y': 45.801577439409826}, 'FRATA': {'name_hun': 'Magyarfráta', 'coords_x': 24.05952346445536, 'coords_y': 46.70548297873597}, 'PLOSCOS': {'name_hun': 'Palackos', 'coords_x': 23.848019562312807, 'coords_y': 46.64324682863738}, 'VALEA IERII': {'name_hun': 'Járavize', 'coords_x': 23.32876543645681, 'coords_y': 46.644099374632816}, 'ICLOD': {'name_hun': 'Nagyiklód', 'coords_x': 23.93892860810773, 'coords_y': 46.210305531372654}, 'FIZESU GHERLII': {'name_hun': 'Ördöngösfüzes', 'coords_x': 23.988215931383923, 'coords_y': 47.025265123800885}, 'CALARASI': {'name_hun': 'Harasztos', 'coords_x': 27.258112662952215, 'coords_y': 47.60540890017327}, 'MAGURI-RACATAU': {'name_hun': 'Reketó', 'coords_x': 23.197003629393212, 'coords_y': 46.64499774692438}, 'SANDULESTI': {'name_hun': 'Szind', 'coords_x': 24.648489903215005, 'coords_y': 45.026835995573734}, 'PALATCA': {'name_hun': 'Magyarpalatka', 'coords_x': 23.988719139371508, '
# ...

# %%
i = 0

for key, value in cities_dict.items():
    cities_dict[key]['name_hun'] = clean_text_accents(value['name_hun'])
    
    i += 1
    
print("Processed %d cities" % i)
# Out:
# Processed 1047 cities

# %%
cities_dict
# Out:
# {'POIENI': {'name_hun': 'Kissebes',
#   'coords_x': 22.45403843259616,
#   'coords_y': 45.801577439409826},
#  'FRATA': {'name_hun': 'Magyarfrata',
#   'coords_x': 24.05952346445536,
#   'coords_y': 46.70548297873597},
#  'PLOSCOS': {'name_hun': 'Palackos',
#   'coords_x': 23.848019562312807,
#   'coords_y': 46.64324682863738},
#  'VALEA IERII': {'name_hun': 'Jaravize',
#   'coords_x': 23.32876543645681,
#   'coords_y': 46.644099374632816},
#  'ICLOD': {'name_hun': 'Nagyiklod',
#   'coords_x': 23.93892860810773,
#   'coords_y': 46.210305531372654},
#  'FIZESU GHERLII': {'name_hun': 'Ordongosfuzes',
#   'coords_x': 23.988215931383923,
#   'coords_y': 47.025265123800885},
#  'CALARASI': {'name_hun': 'Harasztos',
#   'coords_x': 27.258112662952215,
#   'coords_y': 47.60540890017327},
#  'MAGURI-RACATAU': {'name_hun': 'Reketo',
#   'coords_x': 23.197003629393212,
#   'coords_y': 46.64499774692438},
#  'SANDULESTI': {'name_hun': 'Szind',
#   'coords_x': 24.648489903215005,
# ...

# %%
with open('cities_coords_clean.json', 'w') as outfile:
    json.dump(cities_dict, outfile)

# %%
i = 0
city_names = []
for key, value in cities_dict.items():
    city = cities_dict[key]['name_hun']
    city_names.append(city)
    
    i += 1
    
print('i = ', i)
# Out:
# i =  1047

# %%
city_names
# Out:
# ['Kissebes',
#  'Magyarfrata',
#  'Palackos',
#  'Jaravize',
#  'Nagyiklod',
#  'Ordongosfuzes',
#  'Harasztos',
#  'Reketo',
#  'Szind',
#  'Magyarpalatka',
#  'Szek',
#  'Szekelyjo',
#  'Varfalva',
#  'Kiskalota',
#  'Mezocsan',
#  'Doboka',
#  'Kajanto',
#  'Erszollos',
#  'Magyaro',
#  'Szamosujvarnemeti',
#  'Magyarpeterd',
#  'Magyarkapus',
#  'Aranyosgyeres',
#  'Korosfo',
#  'Banffyhunyad',
#  'Alparet',
#  'Kolozsborsa',
#  'Kisbacs',
#  'Egeres',
#  'Jarabanya',
#  'Pusztakamaras',
#  'Torda',
#  'Kolozsvar',
#  'Des',
#  'Havasnagyfalu',
#  'Borsaujfalu',
#  'Recekeresztur',
#  'Szaszfenes',
#  'Magyarszovat',
#  'Josikafalva',
#  'Alsodetrehem',
#  'Meregyo',
#  'Gyalu',
#  'Alsogyekenyes',
#  'Revkolostor',
#  'Kacko',
#  'Alsojara',
#  'Bonchida',
#  'Kereloszentpal',
#  'Csucsa',
#  'Szamosujvar',
#  'Magyargorbo',
#  'Mikefalva',
#  'Magyarkalyan',
#  'Katona',
#  'Roska',
#  'Gyeke',
#  'Kolozs',
#  'Mocs',
#  'Erdofelek',
#  'Pecsetszeg',
#  'Kozarvar',
# ...

# %%
def get_closest_city_name(input_str):
    min_dist = 999
    closest_str = ''
    for elem in city_names:
        dist = textdistance.levenshtein(elem, input_str)

        if dist < min_dist:
            min_dist = dist
            closest_str = elem
    return closest_str

# %%
get_closest_city_name(test_city_name)
# Out:
# 'Szovata'
